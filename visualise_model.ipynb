# %%
! pip install drawconvmet
# Out:
# ERROR: Could not find a version that satisfies the requirement drawconvmet (from versions: none)
# ERROR: No matching distribution found for drawconvmet

# %%
import visualkeras as vk
from keras.models import load_model

# %%
model = r'training_output\face_recognition_vggface.h5'
model = load_model(model)
vk.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=12007x1195>
